# %% [markdown]
# # instalaciones

# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.2-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.4.4-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.2-cp314-cp314-win_amd64.whl (9.9 MB)
# Using cached numpy-2.4.4-cp314-cp314-win_amd64.whl (12.4 MB)
# Using cached tzdata-2026.1-py2.py3-none-any.whl (348 kB)
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...

# %% [markdown]
# # Ejecución

# %%
import pandas as pd

# Ruta del archivo Excel
ruta_archivo = "C:/Users/BOG-LAP-SER-176/Downloads/openair (36).csv"
nombre_hoja = "openair (36)"
nueva_col= "User ID 2"
# Ruta donde se guardará el archivo Excel
ruta_salida = 'C:/Users/BOG-LAP-SER-176/Downloads/tabla_resumen_status.xlsx'


# Usar pd.read_excel() en lugar de pd.read_csv()
#df = pd.read_excel(ruta_archivo, sheet_name=nombre_hoja)
df = pd.read_csv(ruta_archivo, sep=';')

# Limpiar espacios en los nombres de columnas
df.columns = df.columns.str.strip()

# Verificar columnas disponibles
print("Columnas disponibles:", df.columns.tolist())

# Verificar si la columna existe, si no, intentar con sep=','
if nueva_col not in df.columns:
    print(f"Columna '{nueva_col}' no encontrada con sep=';', intentando con sep=','")
    df = pd.read_csv(ruta_archivo, sep=',')
    df.columns = df.columns.str.strip()
    print("Columnas con sep=',':", df.columns.tolist())
# Out:
# Columnas disponibles: ['Date', 'User', 'Service', 'Name', 'Status', 'Start date', 'Time type', 'Client', 'Project', 'Hours', 'Payroll type', 'Group', 'Status.1', 'Invoice #', 'External ID (time)', 'Internal id - project_id', 'Internal id - department - department_id', 'User ID', 'User ID 2']

# %%
df = df[df[nueva_col].isin(['ADRIANA.CASTIBLANCO@BLEND360.COM',
'ALAN.OSORIO@BLEND360.COM',
'ALBA.BELTRAN@BLEND360.COM',
'LEJANDRO.RICO@BLEND360.COM',
'ALEJANDRO.USCATEGUI@NUVU.CC',
'ALEXANDER.ALVARADO@BLEND360.COM',
'ALVARO.CANCINO@BLEND360.COM',
'ANDRES.BARRANTES@BLEND360.COM',
'ANDRES.GUACHETA@BLEND360.COM',
'ANDRES.HUERFANO@BLEND360.COM',
'ANDRES.OTERO@BLEND360.COM',
'ANDRES.POLO@BLEND360.COM',
'ANDRES.PRIETO@BLEND360.COM',
'ANDRES.VEGA@BLEND360.COM',
'ANDRES.MACIAS@BLEND360.COM',
'CHRISTIAN.LOPEZ@BLEND360.COM',
'ANGEL.VILLASMIL@BLEND360.COM',
'SANTIAGO.DIAZ@BLEND360.COM',
'ANGELA.SANTOS@BLEND360.COM',
'ANYELINE.LOZADA@BLEND360.COM',
'ARIANE.HERNANDEZ@BLEND360.COM',
'BRAIDER.URANGO@BLEND360.COM',
'BRANDON.ARDILA@BLEND360.COM',
'HAMET.ANGEL@BLEND360.COM',
'CAMILO.ALVAREZ@BLEND360.COM',
'CARLOS.RAMIREZ@BLEND360.COM',
'CARLOS.SIERRA@BLEND360.COM',
'CARLOS.AROCA@BLEND360.COM',
'CHRISTIAN.GALINDO@BLEND360.COM',
'DANIEL.CORTES@BLEND360.COM',
'CILIANA.CAPERA@BLEND360.COM',
'CRISTHYAN.GUTIERREZ@BLEND360.COM',
'CRISTIAN.SANCHEZ@BLEND360.COM',
'CRISTIAN.CASAS@BLEND360.COM',
'CRISTIAN.CRISTANCHO@BLEND360.COM',
'CRISTIAN.ANGEL@BLEND360.COM',
'DAMIAN.VEGA@BLEND360.COM',
'DANIEL.RODRIGUEZ@BLEND360.COM',
'DANIEL.CASTILLO@BLEND360.COM',
'DAVID.CORTES@BLEND360.COM',
'DANIEL.LOPEZ@BLEND360.COM',
'DANIEL.VARGAS@BLEND360.COM',
'DANIEL.VILLEGAS@BLEND360.COM',
'DANIELA.LIZARAZO@BLEND360.COM',
'DANIELA.LALLE@BLEND360.COM',
'DANIELA.MUNOZ@BLEND360.COM',
'DAVID.BAENA@BLEND360.COM',
'DAVID.SIATAMA@BLEND360.COM',
'DAVID.FORERO@BLEND360.COM',
'DAVID.RODRIGUEZ@BLEND360.COM',
'DAVID.SALCEDO@BLEND360.COM',
'DAVID.JIMENEZ@BLEND360.COM',
'JESSICA.RIVERA@BLEND360.COM',
'DAVID.NARANJO@BLEND360.COM',
'DIANA.VILLAMIZAR@BLEND360.COM',
'DIANA.ROJAS@BLEND360.COM',
'DIEGO.SAAVEDRA@BLEND360.COM',
'DIEGO.BULLA@BLEND360.COM',
'EDWIN.PEREZ@BLEND360.COM',
'ESTEBAN.MARINO@BLEND360.COM',
'ESTEFANIA.VERGARA@BLEND360.COM',
'ESTIVEN.OSPINA@BLEND360.COM',
'ANDRES.GONZALEZ@BLEND360.COM',
'SANTIAGO.BARBOSA@BLEND360.COM',
'FABIO.MURCIA@BLEND360.COM',
'FEDERICO.LIEVANO@BLEND360.COM',
'FEDERICO.ZEA@BLEND360.COM',
'FELIPE.GARZON@BLEND360.COM',
'FELIPE.PARRA@BLEND360.COM',
'FERNANDO.LEON@BLEND360.COM',
'FRANKLIN.GONZALEZ@BLEND360.COM',
'JOSEPH.VERGEL@BLEND360.COM',
'GABRIELA.ZARAZA@BLEND360.COM',
'GERSON.PINEDA@BLEND360.COM',
'GIAN.MORALES@BLEND360.COM',
'GINO.GRIMALDOS@BLEND360.COM',
'GUSTAVO.GALVIS@BLEND360.COM',
'HAROLD.LAMPHREY@BLEND360.COM',
'HAROLD.BURBANO@BLEND360.COM',
'HAROLD.MONCALEANO@BLEND360.COM',
'ALEJANDRO.ALARCON@BLEND360.COM',
'ISABEL.CASTRILLON@BLEND360.COM',
'ISRAEL.VALENZUELA@BLEND360.COM',
'IVAN.BARRERA@BLEND360.COM',
'JAIRO.SALAS@BLEND360.COM',
'JAVIER.SANCHEZ@BLEND360.COM',
'JAVIER.SUAREZ@BLEND360.COM',
'JEAN.GARCIA@BLEND360.COM',
'JEFFERSON.GUTIERREZ@BLEND360.COM',
'JENNIFER.PARRA@BLEND360.COM',
'MARCELA.SANCHEZ@BLEND360.COM',
'JUAN.LEON@BLEND360.COM',
'JESSICA.CASTILLO@BLEND360.COM',
'JESUS.GONZALEZ@BLEND360.COM',
'JESUS.PORTO@BLEND360.COM',
'JHOAN.GARCIA@BLEND360.COM',
'JOAN.MUNOZ@BLEND360.COM',
'ALEJANDRO.ESPITIA@BLEND360.COM',
'JOHAN.ESPITIA@BLEND360.COM',
'JOHAN.ESPINO@BLEND360.COM',
'JOHAN.MANJARRES@BLEND360.COM',
'JOHANN.SOTO@BLEND360.COM',
'ALEJANDRO.MORA@BLEND360.COM',
'JORGE.TORRES@BLEND360.COM',
'JORGE.SIERRA@BLEND360.COM',
'ALEJANDRO.MIGUEZ@BLEND360.COM',
'JOSE.GALLEGO@BLEND360.COM',
'JOSE.SALGADO@BLEND360.COM',
'JOSE.FLOREZ@BLEND360.COM',
'JOSE.RODRIGUEZ@BLEND360.COM',
'GUILLERMO.LOPEZ@BLEND360.COM',
'JOSUE.PESCADOR@BLEND360.COM',
'JULY.RODRIGUEZ@BLEND360.COM',
'JUAN.BERNAL@BLEND360.COM',
'CAMILO.GALLARDO@BLEND360.COM',
'JUAN.ANDRADE@BLEND360.COM',
'JUAN.ZAMBRANO@BLEND360.COM',
'DANIEL.RAMIREZ@BLEND360.COM',
'JUAN.CARRANZA@BLEND360.COM',
'JUAN.FLOREZ@BLEND360.COM',
'JUAN.SANCHEZ@BLEND360.COM',
'JUAN.SILVA@BLEND360.COM',
'JUAN.GOMEZ@BLEND360.COM',
'MIGUEL.SIMBAQUEBA@BLEND360.COM',
'FELIPE.GOMEZ@BLEND360.COM',
'JUANFERNANDO.GARCIA@BLEND360.COM',
'JUAN.SUAREZ@BLEND360.COM',
'NATHALY.PEREZ@BLEND360.COM',
'JUAN.ACOSTA@BLEND360.COM',
'JUAN.CAMARGO@BLEND360.COM',
'JUANPABLO.GARCIA@BLEND360.COM',
'PABLO.CRISTANCHO@BLEND360.COM',
'JUAN.JOYA@BLEND360.COM',
'JUAN.RODRIGUEZ@BLEND360.COM',
'RICARDO.MORENO@BLEND360.COM',
'JUAN.TINJACA@BLEND360.COM',
'JUANA.CHICACAUSA@BLEND360.COM',
'JULIAN.AMAYA@BLEND360.COM',
'JULIAN.OSORIO@BLEND360.COM',
'JULIAN.RINCON@BLEND360.COM',
'JULIAN.CADENA@BLEND360.COM',
'JULIAN.ANGEL@BLEND360.COM',
'JULIANA.DEMIER@BLEND360.COM',
'ANDY.CANO@BLEND360.COM',
'KAREN.ARANDIA@BLEND360.COM',
'KELLY.CARBONELL@BLEND360.COM',
'KEVIN.RINCON@BLEND360.COM',
'LAURA.POVEDA@BLEND360.COM',
'MARCELA.SABOGAL@BLEND360.COM',
'LEIDY.MUNOZ@BLEND360.COM',
'LORENA.VEGA@BLEND360.COM',
'ADRIAN.QUINTERO@BLEND360.COM',
'ANGEL.MARULANDA@BLEND360.COM',
'LUIS.PINZON@BLEND360.COM',
'LUIS.DORDELLY@BLEND360.COM',
'LUIS.MARIN@BLEND360.COM',
'LUIS.ORTIZ@BLEND360.COM',
'FELIPE.BERNAL@BLEND360.COM',
'FELIPE.CASTANEDA@BLEND360.COM',
'FERNANDO.GAITAN@BLEND360.COM',
'FERNANDO.ORTEGA@BLEND360.COM',
'LUIS.VEJARANO@BLEND360.COM',
'HERNANDO.BERNAL@BLEND360.COM',
'LUIS.LOPERA@BLEND360.COM',
'LUISA.SARMIENTO@BLEND360.COM',
'MAGDA.HERRERA@BLEND360.COM',
'MANUEL.GONZALEZ@BLEND360.COM',
'MANUEL.GARCIA@BLEND360.COM',
'MANUEL.QUINTANA@BLEND360.COM',
'ALEJANDRA.GOMEZ@BLEND360.COM',
'ANGELICA.BECERRA@BLEND360.COM',
'PILAR.BELLO@BLEND360.COM',
'MARIBEL.NOVOA@BLEND360.COM',
'MARTHA.ZAMBRANO@BLEND360.COM',
'VIVIANA.VELANDIA@BLEND360.COM',
'MARYITH.GARZON@BLEND360.COM',
'MATEO.FONSECA@BLEND360.COM',
'MAURICIO.CAMPUZANO@BLEND360.COM',
'MAXIMILIANO.PULIDO@BLEND360.COM',
'MELINDA.DURAN@BLEND360.COM',
'DAYANA.JAIMES@BLEND360.COM',
'MIGUEL.CARRILLO@BLEND360.COM',
'MIGUEL.GARCIA@BLEND360.COM',
'GABRIEL.FORERO@BLEND360.COM',
'JOYNER.CABALLERO@BLEND360.COM',
'ARMANDO.AGUILERA@BLEND360.COM',
'JOHAN.VELANDIA@BLEND360.COM',
'ELKIN.BENITEZ@BLEND360.COM',
'JAVIER.ALDANA@BLEND360.COM',
'NATHALY.GARZON@BLEND360.COM',
'MOISES.ROJAS@BLEND360.COM',
'MOISES.JUNCA@BLEND360.COM',
'MONICA.VARELA@BLEND360.COM',
'ANDRES.CAMACHO@BLEND360.COM',
'SANTIAGO.VEGA@BLEND360.COM',
'NICOLAS.ALGARRA@BLEND360.COM',
'NICOLAS.SANCHEZ@BLEND360.COM',
'NICOLAS.REVOLLO@BLEND360.COM',
'NICOLE.GOMEZ@BLEND360.COM',
'NICOLE.ZAPATA@BLEND360.COM',
'OMAIRA.MELO@BLEND360.COM',
'OSCAR.GOMEZ@BLEND360.COM',
'PAOLA.CEPEDA@BLEND360.COM',
'PEDRO.MORA@BLEND360.COM',
'SANTIAGO.BASTOS@BLEND360.COM',
'ANDRES.RODRIGUEZ@BLEND360.COM',
'ROGER.BONILLA@BLEND360.COM',
'RONALD.PORRAS@BLEND360.COM',
'SALOMON.MEJIA@BLEND360.COM',
'SAMUEL.ESCOBAR@BLEND360.COM',
'SANTIAGO.BEDOYA@BLEND360.COM',
'SANTIAGO.GARZON@BLEND360.COM',
'SANTIAGO.VILLEGAS@BLEND360.COM',
'SARA.JIMENEZ@BLEND360.COM',
'SEBASTIAN.ARIZA@BLEND360.COM',
'SEBASTIAN.BARROS@BLEND360.COM',
'SEBASTIAN.VIDAL@BLEND360.COM',
'SEBASTIAN.CASTELBLANCO@BLEND360.COM',
'SEBASTIAN.FANCHI@BLEND360.COM',
'SEBASTIAN.OBANDO@BLEND360.COM',
'SEBASTIAN.SPITTA@BLEND360.COM',
'SERGIO.RODRIGUEZ@BLEND360.COM',
'SIMON.CALDERON@BLEND360.COM',
'SIMON.LOPEZ@BLEND360.COM',
'SOFIA.PERDOMO@BLEND360.COM',
'VALENTINA.GONZALEZ@BLEND360.COM',
'VALENTINA.MANCIPE@BLEND360.COM',
'VALENTINA.SALAZAR@BLEND360.COM',
'VALENTINA.VILLEGAS@BLEND360.COM',
'VICTOR.CASTELLANOS@BLEND360.COM',
'WHITMAN.ROJAS@BLEND360.COM',
'ANDRES.HURTADO@BLEND360.COM',
'YAMIR.CORONADO@BLEND360.COM',
'DANIELA.VARGAS@BLEND360.COM',
'YEISON.MARTINEZ@BLEND360.COM',
'YIDAIDO.ROJAS@BLEND360.COM',
'YOHAN.CADENA@BLEND360.COM',
'YONATHAN.LOPEZ@BLEND360.COM',
'ALEJANDRA.ARDILA@BLEND360.COM'])]

# %%
df
# Out:
#            Date                             User  Service  \
# 0      1/4/2026   ESCOBAR JAIMES, SAMUEL ORLANDO  DSX: US
# 3      1/4/2026     GARCIA FLOREZ, JUAN FERNANDO  DSX: US
# 10     1/4/2026          MANCIPE VEGA, VALENTINA  DSX: US
# 11     1/4/2026                   ZAMBRANO, JUAN  DSX: US
# 12     1/4/2026                   ZAMBRANO, JUAN  DSX: US
# ...         ...                              ...      ...
# 7490  24/4/2026                   ZAMBRANO, JUAN  DSX: US
# 7491  24/4/2026                   ZAMBRANO, JUAN  DSX: US
# 7492  24/4/2026                   ZAMBRANO, JUAN  DSX: US
# 7493  24/4/2026                   ZAMBRANO, JUAN  DSX: US
# 7494  24/4/2026  CASTILLO VELASCO, JESSICA PAOLA  DSX: US
#
#                           Name    Status Start date  Time type  \
# 0     03/29/2026 to 04/04/2026  Approved  3/29/2026        NaN
# 3     03/29/2026 to 04/04/2026  Approved  3/29/2026        NaN
# 10    03/29/2026 to 04/04/2026  Approved  3/29/2026        NaN
# ...

# %%
tabla_resumen_status = df.pivot_table(
    index='User',
    columns='Name',
    values='Status',
    aggfunc=lambda x: ', '.join(sorted(set(x.dropna())))
)

#tabla_resumen_status

# %%
tabla_resumen_status_cloud = df.pivot_table(
    index='User',
    columns='Name',
    values='Status',
    aggfunc=lambda x: ', '.join(sorted(set(x.dropna())))
)

#tabla_resumen_status_cloud

# %%
# Exportar el DataFrame a un archivo Excel
tabla_resumen_status.to_excel(ruta_salida, index=True)
